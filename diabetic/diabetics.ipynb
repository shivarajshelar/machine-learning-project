# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:/work_space/learning/machineLearning/diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
sns.distplot(df['Pregnancies'])
sns.distplot(df['Glucose'])
plt.show()
# Out:
# C:\Users\shiv\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\shiv\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,10))
corr = df.corr()
sns.heatmap(corr,annot=True,cmap="crest")
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df['Age'])
sns.distplot(df['Pregnancies'])
# Out:
# C:\Users\shiv\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\shiv\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Pregnancies', ylabel='Density'>

# %% [markdown]
#  ### KNN model

# %%
x = df.drop(['Outcome'],axis=1)
y = df['Outcome']

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.22,random_state=19)

# %%
accuracy_train = []
accuracy_test = []
for i in range(1,21):
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(x_train,y_train)
    accuracy_train.append(clf.score(x_train,y_train))
    accuracy_test.append(clf.score(x_test,y_test))

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x = range(1,21,1),y = accuracy_train )
sns.lineplot(x = range(1,21,1),y= accuracy_test)
plt.xlabel("neighbours numbers")
plt.ylabel("accuracy")
# Out:
# Text(0, 0.5, 'accuracy')

# %%
clf = KNeighborsClassifier(n_neighbors=8)
clf.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=8)

# %%
y_pred = clf.predict(x_test)

# %% [markdown]
# ### Accuracy

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7751479289940828
